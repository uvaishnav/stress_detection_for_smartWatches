# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('../src')  # Add source directory to path

# %%
from feature_engineering.feature_pipeline import FeatureEngineeringPipeline

# %%
def load_data(file_path: str) -> pd.DataFrame:
    """
    Load sample data from a Parquet file.
    
    Args:
        file_path: Path to the Parquet file
        
    Returns:
        DataFrame containing the data
    """
    print(f"Loading data from {file_path}...")
    df = pd.read_parquet(file_path)
    print(f"Loaded {len(df)} samples with {len(df.columns)} columns")
    return df

# %%
data_path = "../data/cleaned_signal_dataset"
output_dir = "../features"

# %%
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Load Data

# %%
df = load_data(data_path)
# Out:
# Loading data from ../data/cleaned_signal_dataset...
# Loaded 6554753 samples with 24 columns

# %% [markdown]
# ## Print data info

# %%
print("\nData preview:")
print(df.head())
    
print("\nData columns:")
print(df.columns.tolist())
    
print("\nData statistics:")

print(df.describe())
# Out:
# Data preview:
#          bvp  label  subject_id    dataset        device skin_tone  \
# 0   5.673109      0           2  physionet   apple_watch      V-VI
# 1   7.687833      0           2  physionet   apple_watch      I-II
# 2   1.509560      0           2  physionet   apple_watch    III-IV
# 3  12.999866      0           2  physionet  galaxy_watch    III-IV
# 4  20.798602      0           2  physionet  galaxy_watch      V-VI
#
#    noise_level     acc_x      acc_y     acc_z  ...  bvp_smoothed  \
# 0      0.05088 -0.817685 -62.628226  4.996602  ...      1.427777
# 1      0.07712 -0.973498 -62.739436  5.184150  ...      2.176976
# 2      0.06400 -1.054134 -62.992483  5.020381  ...      2.724725
# 3      0.09600 -1.000000 -69.300000  5.000000  ...      5.804123
# 4      0.07632 -1.000000 -69.300000  5.000000  ...      8.756003
#
#    bvp_denoised  heart_rate  pulse_amplitude  ibi  signal_quality  \
# 0      1.330897    78.26087              0.0  0.0        0.548307
# 1      1.507533    78.26087              0.0  0.0        0.548307
# 2      1.294376    78.26087              0.0  0.0        0.548307
# 3      2.927370    78.26087              0.0  0.0        0.548307
# 4      5.327635    78.26087              0.0  0.0        0.548307
#
#    cardiac_energy  snr_local  systolic_peaks  dicrotic_notches
# 0        0.996148   0.056025               0                 0
# 1        0.996148   0.056025               0                 0
# 2        0.996148   0.056025               0                 0
# 3        0.996148   0.056025               0                 0
# 4        0.996148   0.056025               0                 0
#
# [5 rows x 24 columns]
#
# Data columns:
# ['bvp', 'label', 'subject_id', 'dataset', 'device', 'skin_tone', 'noise_level', 'acc_x', 'acc_y', 'acc_z', 'acc_mag', 'combined_noise', 'motion_burst', 'bvp_cleaned', 'bvp_smoothed', 'bvp_denoised', 'heart_rate', 'pulse_amplitude', 'ibi', 'signal_quality', 'cardiac_energy', 'snr_local', 'systolic_peaks', 'dicrotic_notches']
#
# Data statistics:
#                 bvp         label    subject_id   noise_level         acc_x  \
# count  6.554753e+06  6.554753e+06  6.554753e+06  6.554753e+06  6.554753e+06
# mean   3.682249e+00  1.139445e-01  6.293311e+00  6.859382e-02  1.451265e+01
    'device_type': 'apple_watch',
    'sensor_quality': 0.9,
    'wearing_position': 'wrist_top'
}

# %% [markdown]
# # Initialize feature engineering pipeline

# %%
pipeline = FeatureEngineeringPipeline(
    window_size=300,  # 10 seconds at 30 Hz
    overlap=0.5,      # 50% overlap
    sampling_rate=30, # 30 Hz
    output_dir=output_dir,
    device_info=device_info,
    random_state=42
)

# %%
# Define column names
ppg_col = 'bvp_denoised'
acc_x_col = 'acc_x' if 'acc_x' in df.columns else None
acc_y_col = 'acc_y' if 'acc_y' in df.columns else None
acc_z_col = 'acc_z' if 'acc_z' in df.columns else None
metadata_cols = ['device_type'] if 'device_type' in df.columns else None
target_col = 'stress_level' if 'stress_level' in df.columns else None

# %% [markdown]
# ## Run the pipeline

# %%
selected_features = pipeline.run_pipeline(
    df=df,
    ppg_col=ppg_col,
    acc_x_col=acc_x_col,
    acc_y_col=acc_y_col,
    acc_z_col=acc_z_col,
    metadata_cols=metadata_cols,
    target_col=target_col,
    batch_size=100,  # Process 100 windows at a time
    n_features=20,   # Select top 20 features
    visualize=True   # Generate visualizations
)
# Out:
# Starting feature engineering pipeline...
# Extracting features from 6554753 samples...
# Created 43697 windows with 300 samples each and 50% overlap
# Processed batch 1/437
# Processed batch 2/437
# Processed batch 3/437
# Processed batch 4/437
# Processed batch 5/437
# Processed batch 6/437
# Processed batch 7/437
# Processed batch 8/437
# Processed batch 9/437
# Processed batch 10/437
# Processed batch 11/437
# Processed batch 12/437
# Processed batch 13/437
# Processed batch 14/437
# Processed batch 15/437
# Processed batch 16/437
# Processed batch 17/437
# Processed batch 18/437
# Processed batch 19/437
# Processed batch 20/437
# Processed batch 21/437
# Processed batch 22/437
# Processed batch 23/437
# Processed batch 24/437
# Processed batch 25/437
# Processed batch 26/437
# Processed batch 27/437
# Processed batch 28/437
# Processed batch 29/437
# Processed batch 30/437
# Processed batch 31/437
# Processed batch 32/437
# Processed batch 33/437
# Processed batch 34/437
# Processed batch 35/437
# Processed batch 36/437
# Processed batch 37/437
# Processed batch 38/437
# Processed batch 39/437
# Processed batch 40/437
# Processed batch 41/437
# Processed batch 42/437
# Processed batch 43/437
# Processed batch 44/437
# Processed batch 45/437
# Processed batch 46/437
# Processed batch 47/437
# Processed batch 48/437
# Processed batch 49/437
# Processed batch 50/437
# Processed batch 51/437
# Processed batch 52/437
# Processed batch 53/437
# Processed batch 54/437
# Processed batch 55/437
# Processed batch 56/437
# Processed batch 57/437
# Processed batch 58/437
# Processed batch 59/437
# Processed batch 60/437
# Processed batch 61/437
# Processed batch 62/437
# Processed batch 63/437
# Processed batch 64/437
# Processed batch 65/437
# Processed batch 66/437
# Processed batch 67/437
# Processed batch 68/437
# Processed batch 69/437
# Processed batch 70/437
# Processed batch 71/437
# Processed batch 72/437
# Processed batch 73/437
# Processed batch 74/437
# Processed batch 75/437
# Processed batch 76/437
# Processed batch 77/437
# Processed batch 78/437
# Processed batch 79/437
# Processed batch 80/437
# Processed batch 81/437
# Processed batch 82/437
# Processed batch 83/437
# Processed batch 84/437
# Processed batch 365/437
# Processed batch 366/437
# Processed batch 367/437
# Processed batch 368/437
# Processed batch 369/437
# Processed batch 370/437
# Processed batch 371/437
# Processed batch 372/437
# Processed batch 373/437
# Processed batch 374/437
# Processed batch 375/437
# Processed batch 376/437
# Processed batch 377/437
# Processed batch 378/437
# Processed batch 379/437
# Processed batch 380/437
# Processed batch 381/437
# Processed batch 382/437
# Processed batch 383/437
# Processed batch 384/437
# Processed batch 385/437
# Processed batch 386/437
# Processed batch 387/437
# Processed batch 388/437
# Processed batch 389/437
# Processed batch 390/437
# Processed batch 391/437
# Processed batch 392/437
# Processed batch 393/437
# Processed batch 394/437
# Processed batch 395/437
# Processed batch 396/437
# Processed batch 397/437
# Processed batch 398/437
# Processed batch 399/437
# Processed batch 400/437
# Processed batch 401/437
# Processed batch 402/437
# Processed batch 403/437
# Processed batch 404/437
# Processed batch 405/437
# Processed batch 406/437
# Processed batch 407/437
# Processed batch 408/437
# Processed batch 409/437
# Processed batch 410/437
# Processed batch 411/437
# Processed batch 412/437
# Processed batch 413/437
# Processed batch 414/437
# Processed batch 415/437
# Processed batch 416/437
# Processed batch 417/437
# Processed batch 418/437
# Processed batch 419/437
# Processed batch 420/437
# Processed batch 421/437
# Processed batch 422/437
# Processed batch 423/437
# Processed batch 424/437
# Processed batch 425/437
# Processed batch 426/437
# Processed batch 427/437
# Processed batch 428/437
# Processed batch 429/437
# Processed batch 430/437
# Processed batch 431/437
# Processed batch 432/437
# Processed batch 433/437
# Processed batch 434/437
# Processed batch 435/437
# Processed batch 436/437
# Processed batch 437/437
# Extracted 163 features from 43697 windows
# Features saved to ../features/all_features.csv
# Feature metadata saved to ../features/feature_metadata.json
# Warning: Target column not found. Skipping feature selection.
# Generating visualizations in ../features/visualizations...
# Visualizations saved to ../features/visualizations
# Feature engineering pipeline completed successfully!

# %% [markdown]
# # Print selected features

# %%
print("\nSelected features:")
print(selected_features.columns.tolist())
    
print("\nFeature engineering completed successfully!")
print(f"Results saved to {output_dir}")
# Out:
# Selected features:
# ['window_idx', 'start_idx', 'end_idx', 'time_mean', 'time_median', 'time_std', 'time_var', 'time_range', 'time_iqr', 'time_mad', 'time_skew', 'time_kurtosis', 'time_min', 'time_max', 'time_peak_to_peak', 'time_p10', 'time_p25', 'time_p75', 'time_p90', 'time_mean_derivative', 'time_std_derivative', 'time_max_derivative', 'time_mean_2nd_derivative', 'time_std_2nd_derivative', 'time_max_2nd_derivative', 'time_peak_count', 'time_mean_peak_height', 'time_std_peak_height', 'time_mean_peak_interval', 'time_std_peak_interval', 'time_min_peak_interval', 'time_max_peak_interval', 'time_est_heart_rate', 'time_sdnn', 'time_rmssd', 'time_pnn50', 'time_pnn20', 'time_hrv_cv', 'freq_vlf_power', 'freq_lf_power', 'freq_hf_power', 'freq_cardiac_power', 'freq_total_power', 'freq_lf_power_norm', 'freq_hf_power_norm', 'freq_lf_hf_ratio', 'freq_spectral_centroid', 'freq_spectral_spread', 'freq_spectral_skewness', 'freq_spectral_kurtosis', 'freq_spectral_edge_90', 'freq_spectral_edge_95', 'freq_dominant_freq', 'freq_dominant_freq_power', 'freq_second_dominant_freq', 'freq_second_dominant_freq_power', 'freq_cardiac_dominant_freq', 'freq_cardiac_dominant_freq_power', 'freq_spectral_entropy', 'nonlinear_sample_entropy', 'nonlinear_approximate_entropy', 'nonlinear_permutation_entropy', 'nonlinear_sd1', 'nonlinear_sd2', 'nonlinear_sd1_sd2_ratio', 'nonlinear_poincare_area', 'nonlinear_csi', 'nonlinear_cvi', 'nonlinear_dfa_alpha1', 'nonlinear_dfa_alpha2', 'nonlinear_recurrence_rate', 'nonlinear_determinism', 'image_gasf_mean', 'image_gasf_std', 'image_gasf_min', 'image_gasf_max', 'image_gasf_p25', 'image_gasf_p50', 'image_gasf_p75', 'image_gasf_entropy', 'image_gasf_energy', 'image_gasf_diag_mean', 'image_gasf_diag_std', 'image_gasf_triu_mean', 'image_gasf_tril_mean', 'image_gasf_asymmetry', 'image_mtf_mean', 'image_mtf_std', 'image_mtf_min', 'image_mtf_max', 'image_mtf_p25', 'image_mtf_p50', 'image_mtf_p75', 'image_mtf_entropy', 'image_mtf_energy', 'image_mtf_diag_mean', 'image_mtf_diag_std', 'image_mtf_triu_mean', 'image_mtf_tril_mean', 'image_mtf_asymmetry', 'context_acc_x_mean', 'context_acc_x_std', 'context_acc_x_min', 'context_acc_x_max', 'context_acc_x_range', 'context_acc_x_median', 'context_acc_x_iqr', 'context_acc_x_energy', 'context_acc_x_zero_crossings', 'context_acc_x_peak_count', 'context_acc_y_mean', 'context_acc_y_std', 'context_acc_y_min', 'context_acc_y_max', 'context_acc_y_range', 'context_acc_y_median', 'context_acc_y_iqr', 'context_acc_y_energy', 'context_acc_y_zero_crossings', 'context_acc_y_peak_count', 'context_acc_z_mean', 'context_acc_z_std', 'context_acc_z_min', 'context_acc_z_max', 'context_acc_z_range', 'context_acc_z_median', 'context_acc_z_iqr', 'context_acc_z_energy', 'context_acc_z_zero_crossings', 'context_acc_z_peak_count', 'context_acc_mag_mean', 'context_acc_mag_std', 'context_acc_mag_min', 'context_acc_mag_max', 'context_acc_mag_range', 'context_activity_level', 'context_activity_variability', 'context_jerk_mean', 'context_jerk_std', 'context_jerk_max', 'context_acc_dominant_freq', 'context_acc_dominant_power', 'context_ppg_acc_x_corr', 'context_ppg_acc_x_corr_p', 'context_ppg_acc_y_corr', 'context_ppg_acc_y_corr_p', 'context_ppg_acc_z_corr', 'context_ppg_acc_z_corr_p', 'context_ppg_acc_mag_corr', 'context_ppg_acc_mag_corr_p', 'context_motion_artifact_prob', 'context_signal_quality', 'context_ppg_acc_x_max_xcorr', 'context_ppg_acc_x_max_xcorr_lag', 'context_ppg_acc_y_max_xcorr', 'context_ppg_acc_y_max_xcorr_lag', 'context_ppg_acc_z_max_xcorr', 'context_ppg_acc_z_max_xcorr_lag', 'context_device_norm_factor', 'context_ppg_mean_normalized', 'context_ppg_std_normalized', 'context_sensor_quality_factor', 'context_position_factor']
#
# Feature engineering completed successfully!
# Results saved to ../features
